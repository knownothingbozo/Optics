# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'
import h5py
import threading

# %%
# x = [ r, z ]
# c = [ n0, epsilon, lambda ]
def a(x,c):
    return 1+c[1]*np.cos(2*np.pi*x[1]/c[2])
def n (x,c) :
    if x[0] <= a(x,c) :
        return np.sqrt(c[0]**2 - (c[0]**2 - 1.0) * x[0]**2)
    elif x[0] > a(x,c) :
        return 1.0
def dndr (x,c) :
    if x[0] <= a(x,c) :
        return -(c[0]**2-1.0)*x[0]/(a(x,c)*np.sqrt(c[0]**2-(c[0]**2-1)*x[0]**2/a(x,c)))                    
    elif x[0] > a(x,c) : 
        return 0.0
def dndz (x,c) :
    if x[0] <= a(x,c) :
        return -c[1]*np.pi*(c[0]**2-1.0)*x[0]**2*np.sin(2*np.pi*x[1]/c[2])/(c[2]*a(x,c)**2*np.sqrt(c[0]**2-(c[0]**2-1)*x[0]**2/a(x,c)))
    elif x[0] > a(x,c) : 
        return 0.0

# %%
def func ( x,c ) : # x = [r,z]
    return np.array([x[2]/n(x,c)**2,
                     x[3]/n(x,c)**2,
                     dndr(x,c)/n(x,c),
                     dndz(x,c)/n(x,c)])

# %%
def RK(t,x0,c):

    k = np.zeros((4,4),dtype = 'complex64')
    x = np.zeros((t.size,4),dtype = 'complex64')
    x[0] = x0
    h = t[1]-t[0]

    for i in range(1, t.size):
        k[0] = func(x[i-1], c)
        k[1] = func(x[i-1]+h*k[0]/2, c)
        k[2] = func(x[i-1]+h*k[1]/2, c)
        k[3] = func(x[i-1]+h*k[2], c)

        x[i] = x[i-1]+h*(k[0]+2*k[1]+2*k[2]+k[3])/6
    return x

# %%
x0 = np.array([0.9, 0.0, 0.0, 1.0])
c = [2.0, 0.0, 1.0]
t = np.linspace(0, 30, 20000)
res = RK(t,x0, c)

# %%
fig = plt.figure(figsize=(10,4), layout='constrained')
fig.suptitle(r'Ray traced waveguide')
ax1 = fig.add_subplot(1, 1, 1, title='', xlabel=r'$z$', ylabel=r'$r$')
ax1.set_ylim([-2, 2])
x_max = 10.0
ax1.set_xlim([0, x_max])

x = np.linspace(0, x_max, 500)
y = np.linspace(-2, 2, 500)
X, Y = np.meshgrid(x, y)

alpha = np.clip(Y**2, 0,1)

color = np.zeros((Y.shape[0], X.shape[1], 4))  # RGBA
color[..., 0:2] = 1.0  # blue channel
color[..., 3] = alpha  # alpha channel
ax1.imshow(color, extent=[x.min(), x.max(), y.min(), y.max()], origin='lower', aspect='auto')

ax1.plot(res[:,1], res[:,0]);

# %%
fig = plt.figure(figsize=(10,4), layout='constrained')
fig.suptitle(r'Ray traced waveguide')
ax1 = fig.add_subplot(1, 1, 1, title='', xlabel=r'$z$', ylabel=r'$r$')
ax1.set_ylim([-2, 2])
x_max = 10.0
ax1.set_xlim([0, x_max])

x = np.linspace(0, x_max, 500)
y = np.linspace(-2, 2, 500)
X, Y = np.meshgrid(x, y)

alpha = np.clip(Y**2, 0,1)

color = np.zeros((Y.shape[0], X.shape[1], 4))  # RGBA
color[..., 0:2] = 1.0  # blue channel
color[..., 3] = alpha  # alpha channel
ax1.imshow(color, extent=[x.min(), x.max(), y.min(), y.max()], origin='lower', aspect='auto')

t = np.linspace(0, 40, 10000)
c = [2.0, 0.0, 1.0]
for i in [-0.25,-0.5,-0.9,0.25,0.5,0.9] :
    res = RK(t,[i,0,0,1], c)
    ax1.plot(res[:,1], res[:,0]);
# Out:
# Text(0.5, 0.98, 'Ray traced waveguide')
# (-2.0, 2.0)
# (0.0, 10.0)

# %%
def make_rays(min_val, max_val, num_rays, eps, lam):
    fig = plt.figure(figsize=(20,8), layout='constrained')
    fig.suptitle(r'Ray traced waveguide')
    ax1 = fig.add_subplot(1, 1, 1, title='', xlabel=r'$z$', ylabel=r'$r$')
    ax1.set_ylim([-2, 2])
    x_max = 10.0
    ax1.set_xlim([0, x_max])
    
    x = np.linspace(0, x_max, 500)
    y = np.linspace(-2, 2, 500)
    X, Y = np.meshgrid(x, y)
    
    alpha = np.clip(Y**2, 0,1)
    
    color = np.zeros((Y.shape[0], X.shape[1], 4))  # RGBA
    color[..., 0:2] = 1.0  # blue channel
    color[..., 3] = alpha  # alpha channel
    ax1.imshow(color, extent=[x.min(), x.max(), y.min(), y.max()], origin='lower', aspect='auto')
    
    def ray_calc( t, x0, c, res, index ):
        res[index] = RK(t, x0, c)
    
    rays = np.linspace(min_val, max_val, num_rays)
    threads = [None] * num_rays
    res = [None] * num_rays

    t = np.linspace(0, 40, 10000)
    c = [2.0, eps, lam]

    for i in range(len(threads)):
        threads[i] = threading.Thread(target=ray_clac, args=(t,[rays[i],0.0,0.0,1.0],c))
        threads[i].start()
    
    for i in range(len(threads)):
        threads[i].join()
    
    for i in res :
        res = RK(t,[i,0,0,1], c)
        ax1.plot(i[:,1], i[:,0]);

# %%
make_rays(-0.25,0.25,4,0.1,1.0)
# Out:
# Exception in thread Thread-6:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/threading.py", line 1075, in _bootstrap_inner
# Exception in thread Thread-7:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/threading.py", line 1075, in _bootstrap_inner
#     self.run()
#   File "/home/caleb/Jupyter Lab/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 766, in run_closure
#     self.run()
#   File "/home/caleb/Jupyter Lab/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 766, in run_closure
# Exception in thread Thread-8:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/threading.py", line 1075, in _bootstrap_inner
#     self.run()
#   File "/home/caleb/Jupyter Lab/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 766, in run_closure
#     _threading_Thread_run(self)
#   File "/usr/lib/python3.12/threading.py", line 1012, in run
# Exception in thread Thread-9:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/threading.py", line 1075, in _bootstrap_inner
#     self._target(*self._args, **self._kwargs)
# TypeError: 'numpy.ndarray' object is not callable
#     _threading_Thread_run(self)
#   File "/usr/lib/python3.12/threading.py", line 1012, in run
#     self.run()
#   File "/home/caleb/Jupyter Lab/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 766, in run_closure
#     self._target(*self._args, **self._kwargs)
# TypeError: 'numpy.ndarray' object is not callable
#     _threading_Thread_run(self)
#   File "/usr/lib/python3.12/threading.py", line 1012, in run
#     _threading_Thread_run(self)
#   File "/usr/lib/python3.12/threading.py", line 1012, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'numpy.ndarray' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'numpy.ndarray' object is not callable
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 make_rays(-0.25,0.25,4,0.1,1.0)
#
# Cell In[31], line 38, in make_rays(min_val, max_val, num_rays, eps, lam)
#      35     threads[i].join()
#      37 for i in res :
# ---> 38     res = RK(t,[i,0,0,1], c)
#      39     ax1.plot(i[:,1], i[:,0])
#
# Cell In[24], line 9, in RK(t, x0, c)
#       6 h = t[1]-t[0]
#       8 for i in range(1, t.size):
# ----> 9     k[0] = func(x[i-1], c)
#      10     k[1] = func(x[i-1]+h*k[0]/2, c)
#      11     k[2] = func(x[i-1]+h*k[1]/2, c)
#
# Cell In[23], line 2, in func(x, c)
#       1 def func ( x,c ) : # x = [r,z]
# ----> 2     return np.array([x[2]/n(x,c)**2,
#       3                      x[3]/n(x,c)**2,
#       4                      dndr(x,c)/n(x,c),
#       5                      dndz(x,c)/n(x,c)])
#
# TypeError: unsupported operand type(s) for ** or pow(): 'NoneType' and 'int'
